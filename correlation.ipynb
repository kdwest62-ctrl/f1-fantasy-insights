# %% [markdown]
# <a href="https://colab.research.google.com/github/kdwest62-ctrl/f1-fantasy/blob/main/correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

driver1 = input('Driver 1: ')
dataset1 = input("Points progression (use spaces): ").split()
x_axis = list(map(lambda n: int(n), dataset1))

driver2 = input('Driver 2: ')
dataset2 = input("Points progression (use spaces): ").split()
y_axis = list(map(lambda n: int(n), dataset2))

plt.scatter(x_axis, y_axis)
plt.xlabel(driver1)
plt.ylabel(driver2)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

driver = input('Driver: ')
dataset1 = input("Points progression (use spaces): ").split()
x_axis = list(map(lambda n: int(n), dataset1))

constructor = input('Constructor: ')
dataset2 = input("Points progression (use spaces): ").split()
y_axis = list(map(lambda n: int(n), dataset2))

plt.scatter(x_axis, y_axis)
plt.xlabel(driver)
plt.ylabel(constructor)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

constructor1 = input('Constructor 1: ')
dataset1 = input("Points progression (use spaces): ").split()
x_axis = list(map(lambda n: int(n), dataset1))

constructor2 = input('Constructor 2: ')
dataset2 = input("Points progression (use spaces): ").split()
y_axis = list(map(lambda n: int(n), dataset2))

plt.scatter(x_axis, y_axis)
plt.xlabel(constructor1)
plt.ylabel(constructor2)
plt.grid()
plt.show()
